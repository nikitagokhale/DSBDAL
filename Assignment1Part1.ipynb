# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Salary_dataset.csv')

# %%
df = pd.DataFrame(data, columns=['Salary', 'YearsExperience'])
df2 = pd.DataFrame(data, columns=['Salary', 'YearsExperience'])

# %%
print(df)
# Out:
#       Salary  YearsExperience
# 0    39344.0              NaN
# 1    46206.0              1.4
# 2    37732.0              1.6
# 3    43526.0              2.1
# 4    39892.0              2.3
# 5    56643.0              3.0
# 6    60151.0              3.1
# 7    54446.0              3.3
# 8    64446.0              3.3
# 9    57190.0              3.8
# 10   63219.0              4.0
# 11   55795.0              4.1
# 12   56958.0              4.1
# 13   57082.0              NaN
# 14   61112.0              4.6
# 15   67939.0              5.0
# 16   66030.0              5.2
# 17   83089.0              5.4
# 18   81364.0              6.0
# 19       NaN              6.1
# 20   91739.0              6.9
# 21   98274.0              7.2
# 22  101303.0              8.0
# 23  113813.0              8.3
# 24  109432.0              8.8
# 25  105583.0              9.1
# 26  116970.0              9.6
# 27  112636.0              9.7
# 28  122392.0             10.4
# 29       NaN              NaN

# %%
df.isnull()
# Out:
#     Salary  YearsExperience
# 0    False             True
# 1    False            False
# 2    False            False
# 3    False            False
# 4    False            False
# 5    False            False
# 6    False            False
# 7    False            False
# 8    False            False
# 9    False            False
# 10   False            False
# 11   False            False
# 12   False            False
# 13   False             True
# 14   False            False
# 15   False            False
# 16   False            False
# 17   False            False
# 18   False            False
# 19    True            False
# 20   False            False
# 21   False            False
# 22   False            False
# 23   False            False
# 24   False            False
# 25   False            False
# 26   False            False
# 27   False            False
# 28   False            False
# 29    True             True

# %%
df.describe()
# Out:
#               Salary  YearsExperience
# count      28.000000        27.000000
# mean    73725.214286         5.422222
# std     26683.242432         2.684906
# min     37732.000000         1.400000
# 25%     56431.000000         3.300000
# 50%     63832.500000         5.000000
# 75%     99031.250000         7.600000
# max    122392.000000        10.400000

# %%
print(df.shape)
# Out:
# (30, 2)

# %%
df2 = df.copy()

# %%
df.dropna(inplace=True)

# %%
print(df)
# Out:
#       Salary  YearsExperience
# 1    46206.0              1.4
# 2    37732.0              1.6
# 3    43526.0              2.1
# 4    39892.0              2.3
# 5    56643.0              3.0
# 6    60151.0              3.1
# 7    54446.0              3.3
# 8    64446.0              3.3
# 9    57190.0              3.8
# 10   63219.0              4.0
# 11   55795.0              4.1
# 12   56958.0              4.1
# 14   61112.0              4.6
# 15   67939.0              5.0
# 16   66030.0              5.2
# 17   83089.0              5.4
# 18   81364.0              6.0
# 20   91739.0              6.9
# 21   98274.0              7.2
# 22  101303.0              8.0
# 23  113813.0              8.3
# 24  109432.0              8.8
# 25  105583.0              9.1
# 26  116970.0              9.6
# 27  112636.0              9.7
# 28  122392.0             10.4

# %%
df.to_string()
# Out:
# '      Salary  YearsExperience\n1    46206.0              1.4\n2    37732.0              1.6\n3    43526.0              2.1\n4    39892.0              2.3\n5    56643.0              3.0\n6    60151.0              3.1\n7    54446.0              3.3\n8    64446.0              3.3\n9    57190.0              3.8\n10   63219.0              4.0\n11   55795.0              4.1\n12   56958.0              4.1\n14   61112.0              4.6\n15   67939.0              5.0\n16   66030.0              5.2\n17   83089.0              5.4\n18   81364.0              6.0\n20   91739.0              6.9\n21   98274.0              7.2\n22  101303.0              8.0\n23  113813.0              8.3\n24  109432.0              8.8\n25  105583.0              9.1\n26  116970.0              9.6\n27  112636.0              9.7\n28  122392.0             10.4'

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 1 to 28
# Data columns (total 2 columns):
# Salary             26 non-null float64
# YearsExperience    26 non-null float64
# dtypes: float64(2)
# memory usage: 624.0 bytes

# %%
df.corr()
# Out:
#                    Salary  YearsExperience
# Salary           1.000000         0.979115
# YearsExperience  0.979115         1.000000

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
print(df)
# Out:
#       Salary  YearsExperience
# 1    46206.0              1.4
# 2    37732.0              1.6
# 3    43526.0              2.1
# 4    39892.0              2.3
# 5    56643.0              3.0
# 6    60151.0              3.1
# 7    54446.0              3.3
# 8    64446.0              3.3
# 9    57190.0              3.8
# 10   63219.0              4.0
# 11   55795.0              4.1
# 12   56958.0              4.1
# 14   61112.0              4.6
# 15   67939.0              5.0
# 16   66030.0              5.2
# 17   83089.0              5.4
# 18   81364.0              6.0
# 20   91739.0              6.9
# 21   98274.0              7.2
# 22  101303.0              8.0
# 23  113813.0              8.3
# 24  109432.0              8.8
# 25  105583.0              9.1
# 26  116970.0              9.6
# 27  112636.0              9.7
# 28  122392.0             10.4

# %%
x = df['Salary'].mean()
y = df['YearsExperience'].mean()
df2['Salary'].fillna(x, inplace=True)
df2['YearsExperience'].fillna(y, inplace=True)

# %%
df2
# Out:
#            Salary  YearsExperience
# 0    39344.000000         5.396154
# 1    46206.000000         1.400000
# 2    37732.000000         1.600000
# 3    43526.000000         2.100000
# 4    39892.000000         2.300000
# 5    56643.000000         3.000000
# 6    60151.000000         3.100000
# 7    54446.000000         3.300000
# 8    64446.000000         3.300000
# 9    57190.000000         3.800000
# 10   63219.000000         4.000000
# 11   55795.000000         4.100000
# 12   56958.000000         4.100000
# 13   57082.000000         5.396154
# 14   61112.000000         4.600000
# 15   67939.000000         5.000000
# 16   66030.000000         5.200000
# 17   83089.000000         5.400000
# 18   81364.000000         6.000000
# 19   75687.692308         6.100000
# 20   91739.000000         6.900000
# 21   98274.000000         7.200000
# 22  101303.000000         8.000000
# 23  113813.000000         8.300000
# 24  109432.000000         8.800000
# 25  105583.000000         9.100000
# ...

# %%
df2
# Out:
#            Salary  YearsExperience
# 0    39344.000000         5.396154
# 1    46206.000000         1.400000
# 2    37732.000000         1.600000
# 3    43526.000000         2.100000
# 4    39892.000000         2.300000
# 5    56643.000000         3.000000
# 6    60151.000000         3.100000
# 7    54446.000000         3.300000
# 8    64446.000000         3.300000
# 9    57190.000000         3.800000
# 10   63219.000000         4.000000
# 11   55795.000000         4.100000
# 12   56958.000000         4.100000
# 13   57082.000000         5.396154
# 14   61112.000000         4.600000
# 15   67939.000000         5.000000
# 16   66030.000000         5.200000
# 17   83089.000000         5.400000
# 18   81364.000000         6.000000
# 19   75687.692308         6.100000
# 20   91739.000000         6.900000
# 21   98274.000000         7.200000
# 22  101303.000000         8.000000
# 23  113813.000000         8.300000
# 24  109432.000000         8.800000
# 25  105583.000000         9.100000
# ...

# %%
def make_bin(df):
    label_names = ['NewOne', 'Exper', 'Expert']
    cutoff = [1, 5, 8, 11]
    df['Title'] = pd.cut(df['YearsExperience'], cutoff, labels = label_names)
    return df

# %%
newdf = make_bin(df2)

# %%
newdf
# Out:
#            Salary  YearsExperience   Title
# 0    39344.000000         5.396154   Exper
# 1    46206.000000         1.400000  NewOne
# 2    37732.000000         1.600000  NewOne
# 3    43526.000000         2.100000  NewOne
# 4    39892.000000         2.300000  NewOne
# 5    56643.000000         3.000000  NewOne
# 6    60151.000000         3.100000  NewOne
# 7    54446.000000         3.300000  NewOne
# 8    64446.000000         3.300000  NewOne
# 9    57190.000000         3.800000  NewOne
# 10   63219.000000         4.000000  NewOne
# 11   55795.000000         4.100000  NewOne
# 12   56958.000000         4.100000  NewOne
# 13   57082.000000         5.396154   Exper
# 14   61112.000000         4.600000  NewOne
# 15   67939.000000         5.000000  NewOne
# 16   66030.000000         5.200000   Exper
# 17   83089.000000         5.400000   Exper
# 18   81364.000000         6.000000   Exper
# 19   75687.692308         6.100000   Exper
# 20   91739.000000         6.900000   Exper
# ...

# %%
from sklearn import preprocessing
normal = preprocessing.normalize(df2['YearsExperience'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-27c2a3dd9c52> in <module>
#       1 from sklearn import preprocessing
# ----> 2 normal = preprocessing.normalize(df2['YearsExperience'])
#
# /usr/local/lib64/python3.8/site-packages/sklearn/preprocessing/_data.py in normalize(X, norm, axis, copy, return_norm)
#    1815         raise ValueError("'%d' is not a supported axis" % axis)
#    1816
# -> 1817     X = check_array(
#    1818         X,
#    1819         accept_sparse=sparse_format,
#
# /usr/local/lib64/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900             # If input is 1D raise error
#     901             if array.ndim == 1:
# ...
